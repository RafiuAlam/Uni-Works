# %%
list1=[70,65,78,90,85,75,70,60,68,72]
list1.sort()
print(list1)
mean=sum(list1)/len(list1)
print("Mean value of list1 is:",mean)
count1=1
for i in list1:
  if list1.count(i)>count1:
    count1=list1.count(i)
    Mode=i
print("Mode value of list1 is:",Mode)
if len(list1)%2==0:
  n=int(len(list1)/2)
  Median=(list1[n]+list1[n-1])/2
else:
  n=int((len(list1)+1)/2)
  Median=list1[n-1]
print("Median value of list1 is:",Median)
# Out:
# [60, 65, 68, 70, 70, 72, 75, 78, 85, 90]
# Mean value of list1 is: 73.3
# Mode value of list1 is: 70
# Median value of list1 is: 71.0

# %%
import math
list1 = [70,80,75,65,90,95,85,90,70,85]
mean=sum(list1)/len(list1)
sum1=0
for i in list1:
  sum1=sum1+ (i-mean)**2
variance=sum/len(list1)
print("Variance is",variance)
s_dev=math.sqrt(variance)
print("Standard Deviation is:",'%.2f'%s_dev)
# Out:
# Variance is 92.25
# Standard Deviation is: 9.60

# %%
x = [61,65,70,75,80,85,90,95,100]

sum1=0
m = sum(x)/len(x)
for i in range(x):
    sum1 = sum1 + (i-m)**2
sum1/len(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Smritik Sadhukhan\Downloads\Python and Machine Learning Training\PPT_pdf\3. Statistics\statistics.ipynb Cell 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Smritik%20Sadhukhan/Downloads/Python%20and%20Machine%20Learning%20Training/PPT_pdf/3.%20Statistics/statistics.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> x = [61,65,70,75,80,85,90,95,100]
#       <a href='vscode-notebook-cell:/c%3A/Users/Smritik%20Sadhukhan/Downloads/Python%20and%20Machine%20Learning%20Training/PPT_pdf/3.%20Statistics/statistics.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> sum1=0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Smritik%20Sadhukhan/Downloads/Python%20and%20Machine%20Learning%20Training/PPT_pdf/3.%20Statistics/statistics.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> m = sum(x)/len(x)
# ...
